# %% [markdown]
# # Part-1

# %%
# !pip install pandasql
# Out:
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26781 sha256=a30daf50e3243a7f71ff31bc321deaa861b662b60cab0b73c4cad7cc15262a04
#   Stored in directory: /root/.cache/pip/wheels/5c/4b/ec/41f4e116c8053c3654e2c2a47c62b4fca34cc67ef7b55deb7f
# Successfully built pandasql
# ...

# %%
from pandasql import sqldf
import pandas as pd
#team = pd.read_excel('/content/sample_data/Interview Project Data.xlsx', sheet_name='Team Data')
#game = pd.read_excel('/content/sample_data/Interview Project Data.xlsx', sheet_name='Game Data')
#seat = pd.read_excel('/content/sample_data/Interview Project Data.xlsx', sheet_name='Seating Chart')
#price = pd.read_excel('/content/sample_data/Interview Project Data.xlsx', sheet_name='Ticket Price Data')
scan = pd.read_excel('/content/sample_data/Interview Project Data.xlsx', sheet_name='Ticket Scan Data')

# %% [markdown]
# Q1

# %%
example = sqldf("SELECT event_name, CASE WHEN strftime('%w', event_datetime) IN ('0','6','5') THEN 'Weekend' ELSE 'Weekday' END AS wd FROM scan")
example
# Out:
#                                                event_name       wd
# 0       LA Clippers 2018-2019 Game 14 - Dallas - 12/20/18  Weekday
# 1         LA Clippers 2018-2019 Game 23 - Utah - 01/16/19  Weekday
# 2       LA Clippers 2018-2019 Game 13 - Portland - 12/...  Weekday
# 3       LA Clippers 2018-2019 Game 16 - Sacramento - 1...  Weekday
# 4       LA Clippers 2018-2019 Game 14 - Dallas - 12/20/18  Weekday
# ...                                                   ...      ...
# 345468  LA Clippers 2018-2019 Game 13 - Portland - 12/...  Weekday
# 345469  LA Clippers 2018-2019 Game 18 - Philadelphia -...  Weekday
# 345470  LA Clippers 2018-2019 Game 3 - Houston - 10/21/18  Weekend
# 345471  LA Clippers 2018-2019 Game 4 - Washington - 10...  Weekend
# 345472  LA Clippers 2018-2019 Game 8 - San Antonio - 1...  Weekday
#
# [345473 rows x 2 columns]
# ...

# %%
example = sqldf("SELECT count(event_name), CASE WHEN strftime('%w', event_datetime) IN ('0','6','5') THEN 'Weekend' ELSE 'Weekday' END AS wd FROM scan GROUP BY wd")
example
# Out:
#    count(event_name)       wd
# 0             183838  Weekday
# 1             161635  Weekend

# %% [markdown]
# Q2

# %%
example = sqldf("SELECT event_name, count(event_name) FROM scan GROUP BY event_name")
example
# Out:
#                                            event_name  count(event_name)
# 0    LA Clippers 2018-2019 Game 1 - Denver - 10/17/18               8173
# 1   LA Clippers 2018-2019 Game 10 - Phoenix - 11/2...               7648
# 2     LA Clippers 2018-2019 Game 11 - Miami - 12/8/18               8408
# 3   LA Clippers 2018-2019 Game 12 - Toronto - 12/1...               8885
# 4   LA Clippers 2018-2019 Game 13 - Portland - 12/...               7237
# 5   LA Clippers 2018-2019 Game 14 - Dallas - 12/20/18               8351
# 6   LA Clippers 2018-2019 Game 15 - Denver - 12/22/18               7882
# 7   LA Clippers 2018-2019 Game 16 - Sacramento - 1...               9444
# 8   LA Clippers 2018-2019 Game 17 - San Antonio - ...              10089
# 9   LA Clippers 2018-2019 Game 18 - Philadelphia -...               8904
# 10  LA Clippers 2018-2019 Game 19 - Orlando - 01/0...               8291
# 11  LA Clippers 2018-2019 Game 2 - Oklahoma City -...               6343
# ...

# %%
ex=sqldf("SELECT COUNT(event_name), SUBSTR(s.event_name, 1, INSTR(s.event_name, ' - ')-1) as event, SUBSTR(s.event_name, INSTR(s.event_name, ' - ')+1, INSTR(SUBSTR(s.event_name, INSTR(s.event_name, ' - ')+1), ' - ')-1) as Team, SUBSTR(s.event_name, INSTR(SUBSTR(s.event_name, INSTR(s.event_name, ' - ')+1), ' - ')+ INSTR(s.event_name, ' - ')+1) as Date FROM scan s WHERE event_name NOT LIKE '%Los Angeles%' GROUP BY Team ORDER BY count(event_name) DESC LIMIT 4")
ex
# Out:
#    COUNT(event_name)                          event            Team        Date
# 0              19595   LA Clippers 2018-2019 Game 7  - Golden State  - 11/12/18
# 1              18720  LA Clippers 2018-2019 Game 25    - Sacramento  - 01/27/19
# 2              18648   LA Clippers 2018-2019 Game 8   - San Antonio  - 11/15/18
# 3              18067  LA Clippers 2018-2019 Game 29        - Dallas  - 02/25/19

# %%
ex=sqldf("select count(event_name), SUBSTR(s.event_name, 1, INSTR(s.event_name, ' - ')-1) as event, SUBSTR(s.event_name, INSTR(s.event_name, ' - ')+1, INSTR(SUBSTR(s.event_name, INSTR(s.event_name, ' - ')+1), ' - ')-1) as City, SUBSTR(s.event_name, INSTR(SUBSTR(s.event_name, INSTR(s.event_name, ' - ')+1), ' - ')+ INSTR(s.event_name, ' - ')+1) as Date from scan s GROUP BY City ORDER BY count(event_name) DESC LIMIT 3")
ex
# Out:
#    count(event_name)                          event            City        Date
# 0              19595   LA Clippers 2018-2019 Game 7  - Golden State  - 11/12/18
# 1              18954  LA Clippers 2018-2019 Game 27   - Los Angeles  - 01/31/19
# 2              18720  LA Clippers 2018-2019 Game 25    - Sacramento  - 01/27/19

# %% [markdown]
# Q3

# %%
ex=sqldf("SELECT count(event_name), section_name FROM scan s GROUP BY section_name ORDER BY count(event_name) DESC LIMIT 10")
ex
# Out:
#    count(event_name)  section_name
# 0              17117           106
# 1              16861           116
# 2              15760           115
# 3              15478           107
# 4              12911           108
# 5              11075           117
# 6              11060           301
# 7               9103           114
# 8               7961           105
# 9               7744           304

# %% [markdown]
# Q4

# %%
ex=sqldf("select SUBSTR(s.event_name, INSTR(s.event_name, ' - ')+1, INSTR(SUBSTR(s.event_name, INSTR(s.event_name, ' - ')+1), ' - ')-1) as Team, count(event_name) AS Attendance FROM scan s GROUP BY Team ORDER BY count(event_name) DESC")
ex
# Out:
#                Team  Attendance
# 0    - Golden State       19595
# 1     - Los Angeles       18954
# 2      - Sacramento       18720
# 3     - San Antonio       18648
# 4          - Dallas       18067
# 5         - Phoenix       16399
# 6         - Houston       16219
# 7          - Denver       16055
# 8            - Utah       15863
# 9   - Oklahoma City       15780
# 10       - Portland       15099
# 11        - Memphis       14877
# 12         - Boston       10101
# 13       - New York        9432
# 14      - Milwaukee        9159
# 15   - Philadelphia        8904
# 16        - Toronto        8885
# 17       - Brooklyn        8609
# 18        - Chicago        8411
# 19          - Miami        8408
# 20        - Orlando        8291
# 21      - Cleveland        8032
# 22     - Washington        8019
# 23        - Detroit        7996
# 24      - Minnesota        7985
# 25        - Atlanta        7924
# 26    - New Orleans        7156
# 27        - Indiana        7012
# ...

# %%
ex=sqldf("SELECT City, `Vegas Odds for 1819` FROM team t ORDER BY `Vegas Odds for 1819` DESC")
ex
# Out:
#              City  Vegas Odds for 1819
# 0         Oakland                 62.5
# 1          Boston                 57.5
# 2    Philadelphia                 54.5
# 3         Toronto                 54.5
# 4         Houston                 54.5
# 5   Oklahoma City                 50.5
# 6            Utah                 48.5
# 7     Los Angeles                 48.5
# 8          Denver                 47.5
# 9         Indiana                 47.5
# 10      Milwaukee                 46.5
# 11    New Orleans                 45.5
# 12      Minnesota                 44.5
# 13     Washington                 44.5
# 14    San Antonio                 43.5
# 15          Miami                 41.5
# 16       Portland                 41.5
# 17        Detroit                 37.5
# 18    Los Angeles                 35.5
# 19      Charlotte                 35.5
# 20        Memphis                 34.5
# 21         Dallas                 34.5
# 22       Brooklyn                 32.5
# ...

# %% [markdown]
# Q5

# %%
scan['event_datetime']=scan['event_datetime']+pd.Timedelta(hours=2)

# %%
scan['diff'] = (scan['event_datetime'] - scan['scan_datetime'])/pd.Timedelta(minutes=1)

# %%
scan['diff']
# Out:
# 0         39.250000
# 1         27.866667
# 2         35.133333
# 3         22.500000
# 4        -25.300000
#             ...
# 345468    87.266667
# 345469    33.400000
# 345470   -43.950000
# 345471    30.600000
# 345472    66.916667
# Name: diff, Length: 345473, dtype: float64

# %%
ex=sqldf("SELECT count(event_name),diff FROM scan GROUP BY diff ORDER BY count(event_name) DESC")
ex
# Out:
#        count(event_name)        diff
# 0                    111   12.083333
# 1                    108    5.933333
# 2                    108   10.516667
# 3                    101    5.900000
# 4                    100   -0.616667
# ...                  ...         ...
# 14403                  1  245.083333
# 14404                  1  245.183333
# 14405                  1  245.300000
# 14406                  1  245.416667
# 14407                  1  245.550000
#
# [14408 rows x 2 columns]

# %% [markdown]
# # Part-2

# %%
# !pip install pandasql

# %%
import numpy as np
import pandas as pd
from pandasql import sqldf
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_excel('/content/sample_data/Interview Project Data.xlsx', sheet_name='Ticket Scan Data')
df['Dates'] = pd.to_datetime(df['event_datetime']).dt.date
df['Time'] = pd.to_datetime(df['event_datetime']).dt.time
df['Year'] = pd.DatetimeIndex(df['Dates']).year

# %%
example = sqldf("SELECT year, event_name, event_datetime, scan_datetime, Dates, Time, count(event_name) as Attendance FROM df GROUP BY Dates")
example.head()
# Out:
#    Year  ... Attendance
# 0  2018  ...       8173
# 1  2018  ...       6343
# 2  2018  ...       8009
# 3  2018  ...       8019
# 4  2018  ...       7985
#
# [5 rows x 7 columns]

# %%
example.describe()
example.set_index('Year',inplace=True)

from pylab import rcParams
rcParams['figure.figsize'] = 15, 7
example.plot()

# %%
from statsmodels.tsa.stattools import adfuller
test_result=adfuller(example['Attendance'])

def AdfullerTest(attendance):
    result=adfuller(attendance)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

result=adfuller(example['Attendance'])
if result[1] <= 0.05:
    print("Data is stationary")
else:
    print("Data is non-stationary ")

AdfullerTest(example['Attendance'])
#Here P-value is 0.36 which is greater than 0.05, which means data is accepting the null hypothesis, which means data is non-stationary.
#As mentioned before, a time series must be stationary for it to be used to predict well founded values
#The null hypothesis is that the term is not significantly different from 0, which indicates that no association exists between the term and the response.
# Out:
# Data is stationary
# ADF Test Statistic : -4.712016179063749
# p-value : 7.98859936068291e-05
# #Lags Used : 0
# Number of Observations : 40

# %%
example['Attendance First Difference'] = example['Attendance'] - example['Attendance'].shift(1)
example['Seasonal First Difference']=example['Attendance']-example['Attendance'].shift(12)
example.head()
# Out:
#             Sales  Attendane First Difference  Seasonal First Difference
# Year
# 2018-10-17   8173                         NaN                        NaN
# 2018-10-19   6343                     -1830.0                        NaN
# 2018-10-21   8009                      1666.0                        NaN
# 2018-10-28   8019                        10.0                        NaN
# 2018-11-05   7985                       -34.0                        NaN

# %%
adfuller_test(example['Seasonal First Difference'].dropna())
# Out:
# ADF Test Statistic : -5.075472419573007
# p-value : 1.5701549896326226e-05
# #Lags Used : 0
# Number of Observations : 28

# %%
example['Seasonal First Difference'].plot()

# %%
example['Seasonal First Difference'].plot()
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(example['Sales'])
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import statsmodels.api as sm
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(example['Seasonal First Difference'].dropna(),lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(example['Seasonal First Difference'].dropna(),lags=40,ax=ax2)

# %%
from statsmodels.tsa.arima_model import ARIMA
model=ARIMA(example['Sales'],order=(1,1,1))
model_fit=model.fit()
model_fit.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.Sales   No. Observations:                   40
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -332.110
# Method:                       css-mle   S.D. of innovations            937.837
# Date:                Mon, 10 Jan 2022   AIC                            672.221
# ...

# %%
example['forecast']=model_fit.predict(start=30,end=40,dynamic=True)
example[['Sales','forecast']].plot(figsize=(12,8))

# %%
import statsmodels.api as sm
model=sm.tsa.statespace.SARIMAX(example['Sales'],order=(1, 1, 1),seasonal_order=(1,1,1,12))
results=model.fit()
example['forecast']=results.predict(start=30,end=40,seasonal_order=(1,1,1,12)dynamic=True)
example[['Sales','forecast']].plot(figsize=(12,8))
